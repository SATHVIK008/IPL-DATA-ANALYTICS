# %%
pip install pandas

# %%
pip install tk
# Out:
# Requirement already satisfied: tk in c:\users\hp\anaconda3\lib\site-packages (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime

# %%
players=pd.read_csv('https://docs.google.com/spreadsheets/d/1kj3GIhLYi6xklFo9XCIIHzBHp_AL4EZ4xtJ0HRGhRKk/gviz/tq?tqx=out:csv')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1273             raise CannotSendHeader()
# -> 1274         self._send_output(message_body, encode_chunked=encode_chunked)
#    1275
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1033         del self._buffer[:]
# -> 1034         self.send(msg)
#    1035
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# ~\anaconda3\lib\http\client.py in connect(self)
#    1440
# -> 1441             super().connect()
#    1442
#
# ~\anaconda3\lib\http\client.py in connect(self)
#     944         """Connect to the host and port specified in __init__."""
# --> 945         self.sock = self._create_connection(
#     946             (self.host,self.port), self.timeout, self.source_address)
#
# ~\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     822     err = None
# --> 823     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     824         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14340/1960120540.py in <module>
# ----> 1 players=pd.read_csv('https://docs.google.com/spreadsheets/d/1kj3GIhLYi6xklFo9XCIIHzBHp_AL4EZ4xtJ0HRGhRKk/gviz/tq?tqx=out:csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     607
#     608     # open URLs
# --> 609     ioargs = _get_filepath_or_buffer(
#     610         path_or_buf,
#     611         encoding=encoding,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     310         # assuming storage_options is to be interpreted as headers
#     311         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 312         with urlopen(req_info) as req:
#     313             content_encoding = req.headers.get("Content-Encoding", None)
#     314             if content_encoding == "gzip":
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in urlopen(*args, **kwargs)
#     210     import urllib.request
#     211
# --> 212     return urllib.request.urlopen(*args, **kwargs)
#     213
#     214
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
# -> 1349                 raise URLError(err)
#    1350             r = h.getresponse()
#    1351         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
z=[]
for i in range(len(players)):
    z.append(players['Matches Played Together'][i]+players['Matches Played As Opponents'][i])

# %%
b = (z - np.min(z))/np.ptp(z)
b=list(b)
players['Score_for_chem']=b

# %%
def chemistry(x,y):
    X=players[players['Player 1']==x]
    Y=X[X['Player 2']==y]
    return Y['Score_for_chem'].values[0]

# %%
def one_vs_team_experience_score(x,y):
    c=0
    s=0
    for i in y:
        X=players[players['Player 1']==x]
        Y=X[X['Player 2']==i]
        try:            
            z=Y['Score_for_chem'].values[0]

        except:
            z=0
        if z!=0:
            c+=1
            s+=z
    try:
        m=s/c
    except:
        m=0
    return m

# %%
def team_vs_team_experience_score(x,y):
    s=0
    
    for i in y:
        
        s=s+one_vs_team_experience_score(i,y)
    return s/11

# %%
def stats(x,y):
    X=players[players['Player 1']==x]
    Y=X[X['Player 2']==y]
    try:
        return Y['Stats Points Player 1'].values[0]
    except:
        return 0

# %%
def one_vs_team_stats(x,y):
    s=0
    for i in y:
        
        s=s+stats(x,i)
    return s

# %%
def team_vs_team_stats(x,y):
    s=0
    for i in x:
        s=s+one_vs_team_stats(i,y)
    return s

# %%
#https://docs.google.com/spreadsheets/d/1MlYYb_5VFZTot9-1GCGfvrFuyo0guyT0St5btkvG1tA/gviz/tq?tqx=out:csv
def teams():
    x={}
    teams=pd.read_csv('https://docs.google.com/spreadsheets/d/1MlYYb_5VFZTot9-1GCGfvrFuyo0guyT0St5btkvG1tA/gviz/tq?tqx=out:csv')
    display(teams)
    display(teams.columns)
    x['CSK']=list(teams[teams['CSK']==1]['Name'].values)
    x['RCB']=list(teams[teams['RCB']==1]['Name'].values)
    x['SRH']=list(teams[teams['SRH']==1]['Name'].values)
    x['GT']=list(teams[teams['GT']==1]['Name'].values)
    x['LSG']=list(teams[teams['LSG']==1]['Name'].values)
    x['MI']=list(teams[teams['MI']==1]['Name'].values)
    x['KKR']=list(teams[teams['KKR']==1]['Name'].values)
    x['PK']=list(teams[teams['PK']==1]['Name'].values)
    x['DC']=list(teams[teams['DC']==1]['Name'].values)
    x['RR']=list(teams[teams['RR']==1]['Name'].values)
    return x

# %%
def test_player_in_team(team,player,y):
    #player='NLTC Perera'
    #team='RR'
    y[team].append(player)
    
    m=[i for i in y.keys() if i!=team]
    z={'Against Team':[],'Experience Score Team 1':[],'Stats Score Team 1':[],'Overall Team 1':[],
       'Experience Score Team 2':[],'Stats Score Team 2':[],'Overall Team 2':[]}
    for i in m:
        
        a=team_vs_team_experience_score(y[team],y[i])
        b=team_vs_team_stats(y[team],y[i])
        a2=team_vs_team_experience_score(y[i],y[team])
        b2=team_vs_team_stats(y[i],y[team])
        z['Against Team'].append(i)
        z['Experience Score Team 1'].append(a)
        z['Stats Score Team 1'].append(b)
        z['Experience Score Team 2'].append(a2)
        z['Stats Score Team 2'].append(b2)
        z['Overall Team 1'].append(a*10+b)
        z['Overall Team 2'].append(a2*10+b2)
    z=pd.DataFrame(z)
    return z

# %%
teams()
# Out:
#              Name  CSK  RCB  MI  GT  LSG  PK  SRH  RR  KKR  DC  Sold   Unsold  \
# 0            Test  NaN  1.0 NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 1       RG Sharma  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 2         V Kohli  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 3        SK Raina  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 4       DA Warner  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# ..            ...  ...  ...  ..  ..  ...  ..  ...  ..  ...  ..    ...     ...
# 186        P Negi  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 187    AB Agarkar  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 188   NLTC Perera  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 189  MC Henriques  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 190  DT Christian  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
#
#      Amount (in lakhs)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 186                NaN
# 187                NaN
# 188                NaN
# 189                NaN
# 190                NaN
#
# [191 rows x 14 columns]
# Index(['Name', 'CSK', 'RCB', 'MI', 'GT', 'LSG', 'PK', 'SRH', 'RR', 'KKR', 'DC',
#        'Sold ', 'Unsold', 'Amount (in lakhs)'],
#       dtype='object')
# {'CSK': [],
#  'RCB': ['Test'],
#  'SRH': [],
#  'GT': [],
#  'LSG': [],
#  'MI': [],
#  'KKR': [],
#  'PK': [],
#  'DC': [],
#  'RR': []}

# %%
def team_with_player(team,player):
    x=teams()
    return test_player_in_team(team,player,x)

# %%
def teamOverAll(x,z):
    a=0
    b=0
    
    y={'Team 1':[] ,'Team 2': [],'Team 1 Wins':[] ,'Team 2 Wins':[] }
    for i in t_lst_1:
        if i !=x:
            y['Team 1'].append(x)
            y['Team 2'].append(i)
            a1=team_vs_team_experience_score(z[x],z[i])
            b1=team_vs_team_stats(z[x],z[i])
            c1=a1+b1
            a2=team_vs_team_experience_score(z[i],z[x])
            b2=team_vs_team_stats(z[i],z[x])
            c2=a2+b2
            if c1>=c2:
                y['Team 1 Wins'].append(True)
                y['Team 2 Wins'].append(False)
            else:
                y['Team 2 Wins'].append(True)
                y['Team 1 Wins'].append(False)
    y=pd.DataFrame(y)
    a=len(y[y['Team 1 Wins']==True])
    #display(y)
    print('Total wins for {} is {}'.format(x,a))
    return y,a

# %%
def teamWithTeam(team1,team2):
    x=teams()
    
    z={'Team 1':[],'Team 2':[],'Experience Score Team 1':[],'Stats Score Team 1':[],'Overall Team 1':[],
       'Experience Score Team 2':[],'Stats Score Team 2':[],'Overall Team 2':[]}
    a=team_vs_team_experience_score(x[team1],x[team2])
    b=team_vs_team_stats(x[team1],x[team2])
    a2=team_vs_team_experience_score(x[team2],x[team1])
    b2=team_vs_team_stats(x[team2],x[team1])
    z['Team 1']=team1
    z['Team 2']=team2
    z['Experience Score Team 1'].append(a)
    z['Stats Score Team 1'].append(b)
    z['Experience Score Team 2'].append(a2)
    z['Stats Score Team 2'].append(b2)
    z['Overall Team 1'].append(a*10+b)
    z['Overall Team 2'].append(a2*10+b2)

    z=pd.DataFrame(z)
    
    return z

# %%
p=pd.read_csv('https://docs.google.com/spreadsheets/d/1MlYYb_5VFZTot9-1GCGfvrFuyo0guyT0St5btkvG1tA/gviz/tq?tqx=out:csv')
m=pd.read_csv('https://docs.google.com/spreadsheets/d/1zhpcj7_6Uq96UDNEi3ZS-bu5B3AXCXSRDeiHy0nvvfE/gviz/tq?tqx=out:csv')

# %%
from tkinter import *
import numpy as np
import pandas as pd
from tkinter import Tk, Button, Frame, StringVar
from tkinter.ttk import Combobox
from tkinter import ttk

# %%
#this for player
p_lst_1 = list(p['Name'])
p_lst_1.sort()

#this for team
t_lst_1 = ['CSK', 'RCB', 'SRH', 'GT', 'LSG', 'MI', 'KKR', 'PK', 'DC', 'RR']
t_lst_1.sort()

# %% [markdown]
# # The below Cell tells if you add a player to a particular team how will the stats respond

# %%
root = Tk()
root.configure(bg='light blue')
root.title("IPL DATABID -PLAYER AUCTION")

def get_info():
    top = Toplevel()
    team=cb1_var.get()
    player=cb2_var.get()
    print("For {} in {} team".format(player,team))
    x=team_with_player(team,player)
    text=Text(top,width=80, height=15)
    text.insert(END,x)
    text.grid()
    
    
root.geometry("500x300")
cb1_var = StringVar()

cb1 = ttk.Label(root, text = "Team :", background = 'light blue',
          font = ("Times New Roman", 10)).grid(column = 0,
          row = 5, padx = 10, pady = 25)
cb1 = ttk.Combobox(root, width = 27, values=t_lst_1, textvariable = cb1_var)
cb1.grid(column = 1, row = 5)


cb2_var = StringVar()

cb2 = ttk.Label(root, text = "Player :",background = 'light blue',
          font = ("Times New Roman", 10)).grid(column = 2,
          row = 5, padx = 5, pady = 15)

   
cb2 = ttk.Combobox(root, width = 27, values=p_lst_1,textvariable = cb2_var)
cb2.grid(column=3, row =5)  



Button(root, text='Confirm', command=get_info).grid(row=7,column=2,padx=1)


root.mainloop()
# Out:
# For A Kumble in GT team
#              Name  CSK  RCB  MI  GT  LSG  PK  SRH  RR  KKR  DC  Sold   Unsold  \
# 0            Test  NaN  1.0 NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 1       RG Sharma  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 2         V Kohli  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 3        SK Raina  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 4       DA Warner  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# ..            ...  ...  ...  ..  ..  ...  ..  ...  ..  ...  ..    ...     ...
# 186        P Negi  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 187    AB Agarkar  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 188   NLTC Perera  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 189  MC Henriques  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 190  DT Christian  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
#
#      Amount (in lakhs)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 186                NaN
# 187                NaN
# 188                NaN
# 189                NaN
# 190                NaN
#
# [191 rows x 14 columns]
# Index(['Name', 'CSK', 'RCB', 'MI', 'GT', 'LSG', 'PK', 'SRH', 'RR', 'KKR', 'DC',
#        'Sold ', 'Unsold', 'Amount (in lakhs)'],
#       dtype='object')
# For RG Sharma in GT team
#              Name  CSK  RCB  MI  GT  LSG  PK  SRH  RR  KKR  DC  Sold   Unsold  \
# 0            Test  NaN  1.0 NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 1       RG Sharma  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 2         V Kohli  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 3        SK Raina  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 4       DA Warner  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# ..            ...  ...  ...  ..  ..  ...  ..  ...  ..  ...  ..    ...     ...
# 186        P Negi  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 187    AB Agarkar  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 188   NLTC Perera  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 189  MC Henriques  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 190  DT Christian  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
#
#      Amount (in lakhs)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 186                NaN
# 187                NaN
# 188                NaN
# 189                NaN
# 190                NaN
#
# [191 rows x 14 columns]
# Index(['Name', 'CSK', 'RCB', 'MI', 'GT', 'LSG', 'PK', 'SRH', 'RR', 'KKR', 'DC',
#        'Sold ', 'Unsold', 'Amount (in lakhs)'],
#       dtype='object')

# %% [markdown]
# # Below code will help you find stats between two teams

# %%
root = Tk()

root.configure(bg='light blue')
root.title("IPL DATABID -PLAYER AUCTION")
def get_info():
    top = Toplevel()
    team1=cb1_var.get()
    team2=cb2_var.get()
    print("For {} vs {} ".format(team1,team2))
    x=teamWithTeam(team1,team2)
    text=Text(top,width=80, height=15)
    text.insert(END,x)
    text.grid()
    
    

root.geometry("500x300")
cb1_var = StringVar()

cb1 = ttk.Label(root, text = "Team 1 :", background = 'light blue',
          font = ("Times New Roman", 10)).grid(column = 0,
          row = 5, padx = 10, pady = 25)
cb1 = ttk.Combobox(root, width = 27, values=t_lst_1, textvariable = cb1_var)
cb1.grid(column = 1, row = 5)



cb2_var = StringVar()

cb2 = ttk.Label(root, text = "Team 2 :",background = 'light blue',
          font = ("Times New Roman", 10)).grid(column = 2,
          row = 5, padx = 5, pady = 15)

   
cb2 = ttk.Combobox(root, width = 27, values=t_lst_1,textvariable = cb2_var)
cb2.grid(column=3, row =5)  



Button(root, text='Confirm', command=get_info).grid(row=7,column=2,padx=1)


root.mainloop()
# Out:
# For KKR vs DC
#              Name  CSK  RCB  MI  GT  LSG  PK  SRH  RR  KKR  DC  Sold   Unsold  \
# 0            Test  NaN  1.0 NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 1       RG Sharma  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 2         V Kohli  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 3        SK Raina  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 4       DA Warner  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# ..            ...  ...  ...  ..  ..  ...  ..  ...  ..  ...  ..    ...     ...
# 186        P Negi  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 187    AB Agarkar  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 188   NLTC Perera  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 189  MC Henriques  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 190  DT Christian  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
#
#      Amount (in lakhs)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 186                NaN
# 187                NaN
# 188                NaN
# 189                NaN
# 190                NaN
#
# [191 rows x 14 columns]
# Index(['Name', 'CSK', 'RCB', 'MI', 'GT', 'LSG', 'PK', 'SRH', 'RR', 'KKR', 'DC',
#        'Sold ', 'Unsold', 'Amount (in lakhs)'],
#       dtype='object')

# %% [markdown]
# # The below code will help you to know about Player vs Player stats

# %%
root = Tk()

root.configure(bg='light blue')
root.title("IPL DATABID -PLAYER AUCTION")
def get_info():
    top = Toplevel()
    player1=cb1_var.get()
    player2=cb2_var.get()
    print("For {} vs {} ".format(player1,player2))
    x1=chemistry(player1,player2)
    x2=stats(player1,player2)
    x3=stats(player2,player1)
    x={'Player 1':[player1],'Player 2':[player2],'Chemistry':[x1],
        'Stats Player 1':[x2],'Stats Player 2':[x3]}
    x=pd.DataFrame(x)
    text=Text(top,width=80, height=15)
    text.insert(END,x)
    text.grid()
    
    

root.geometry("500x300")
cb1_var = StringVar()

cb1 = ttk.Label(root, text = "Player 1 :", background = 'light blue',
          font = ("Times New Roman", 10)).grid(column = 0,
          row = 5, padx = 10, pady = 25)
cb1 = ttk.Combobox(root, width = 27, values=p_lst_1, textvariable = cb1_var)
cb1.grid(column = 1, row = 5)



cb2_var = StringVar()

cb2 = ttk.Label(root, text = "Player 2 :",background = 'light blue',
          font = ("Times New Roman", 10)).grid(column = 2,
          row = 5, padx = 5, pady = 15)

   
cb2 = ttk.Combobox(root, width = 27, values=p_lst_1,textvariable = cb2_var)
cb2.grid(column=3, row =5)  



Button(root, text='Confirm', command=get_info).grid(row=7,column=2,padx=1)


root.mainloop()
# Out:
# For A Nortje vs Avesh Khan

# %% [markdown]
# # The below code will explain about winning and losing status with your current team formed

# %%
root = Tk()

root.configure(bg='light blue')
root.title("IPL DATABID -PLAYER AUCTION")
#root.iconphoto(False,p1)
def get_info():
    top = Toplevel()
    team=cb1_var.get()
    z=teams()
    x,a=teamOverAll(team,z)
    text=Text(top,width=80, height=15)
    text.insert(END,x)
    text.grid()
    #print(x)

root.geometry("500x300")
cb1_var = StringVar()


cb1 = ttk.Label(root, text = "Team 1 :", background = 'light blue',
          font = ("Times New Roman", 10)).grid(column = 0,
          row = 5, padx = 10, pady = 25)
cb1 = ttk.Combobox(root, width = 27, values=t_lst_1, textvariable = cb1_var)
cb1.grid(column = 1, row = 5)


Button(root, text='Confirm', command=get_info).grid(row=7,column=2,padx=1)


root.mainloop()

# %% [markdown]
# # The below code will help you to find the final Points table

# %%
z=teams()
p={'Team':[],'Points':[]}
for i in t_lst_1:
    m,k=teamOverAll(i,z)
    p['Team'].append(i)
    p['Points'].append(k*2)
p=pd.DataFrame(p)
p=p.sort_values('Points',ascending=False)
display(p)
# Out:
#              Name  CSK  RCB  MI  GT  LSG  PK  SRH  RR  KKR  DC  Sold   Unsold  \
# 0            Test  NaN  1.0 NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 1       RG Sharma  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 2         V Kohli  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 3        SK Raina  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 4       DA Warner  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# ..            ...  ...  ...  ..  ..  ...  ..  ...  ..  ...  ..    ...     ...
# 186        P Negi  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 187    AB Agarkar  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 188   NLTC Perera  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 189  MC Henriques  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
# 190  DT Christian  NaN  NaN NaN NaN  NaN NaN  NaN NaN  NaN NaN    NaN     NaN
#
#      Amount (in lakhs)
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 186                NaN
# 187                NaN
# 188                NaN
# 189                NaN
# 190                NaN
#
# [191 rows x 14 columns]
# Index(['Name', 'CSK', 'RCB', 'MI', 'GT', 'LSG', 'PK', 'SRH', 'RR', 'KKR', 'DC',
#        'Sold ', 'Unsold', 'Amount (in lakhs)'],
#       dtype='object')
# Total wins for CSK is 8
# Total wins for DC is 3
# Total wins for GT is 1
# Total wins for KKR is 2
# Total wins for LSG is 7
# Total wins for MI is 5
# Total wins for PK is 9
# Total wins for RCB is 3
# Total wins for RR is 9
# Total wins for SRH is 3
#   Team  Points
# 6   PK      18
# 8   RR      18
# 0  CSK      16
# 4  LSG      14
# 5   MI      10
# 1   DC       6
# 7  RCB       6
# 9  SRH       6
# 3  KKR       4
# 2   GT       2
